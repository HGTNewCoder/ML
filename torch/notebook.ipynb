# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import sklearn
from sklearn.linear_model import RidgeCV, LinearRegression, Ridge

# %%
X = np.array([[147, 150, 153, 158, 163, 168, 170, 173, 175, 178, 180, 183]]).T # 12 1
Y = np.array([[49, 50, 51, 54, 58, 60, 62, 63, 64, 66, 67, 68]]).T # 12 1

# %%
model = LinearRegression()
model.fit(X, Y)

weight = model.coef_[0]
bias = model.intercept_[0]

X_pred = np.arange(140, 190, 1)
Y_pred = weight*X_pred + bias

plt.scatter(X, Y)
plt.plot(X_pred, Y_pred)

# %%
model = RidgeCV()
model.fit(X, Y)

weight = model.coef_[0]
bias = model.intercept_[0]

X_pred = np.arange(140, 190, 1)
Y_pred = weight*X_pred + bias

plt.scatter(X, Y)
plt.plot(X_pred, Y_pred)

# %%
model = Ridge()
model.fit(X, Y)

weight = model.coef_[0]
bias = model.intercept_[0]

X_pred = np.arange(140, 190, 1)
Y_pred = weight*X_pred + bias

plt.scatter(X, Y)
plt.plot(X_pred, Y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 model = Ridge()
#       2 model.fit(X, Y)
#       4 weight = model.coef_[0]
#
# NameError: name 'Ridge' is not defined
